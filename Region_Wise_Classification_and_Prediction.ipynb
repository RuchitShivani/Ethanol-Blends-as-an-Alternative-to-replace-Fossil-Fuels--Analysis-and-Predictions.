# %% [markdown]
# <a href="https://colab.research.google.com/github/RuchitShivani/Ethanol-Blends-as-an-Alternative-to-replace-Fossil-Fuels--Analysis-and-Predictions./blob/main/Region_Wise_Classification_and_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries (only for Google Colab, uncomment if needed)
# !pip install prophet

# Import libraries
import pandas as pd

# Load dataset
df = pd.read_csv("renewable_energy.csv")

# Complete country-to-region mapping (includes all 48 Asian countries)
region_mapping = {
    # North America
    'USA': 'North America', 'CAN': 'North America', 'MEX': 'North America',

    # South America
    'BRA': 'South America', 'ARG': 'South America', 'CHL': 'South America', 'COL': 'South America', 'PER': 'South America',

    # Europe
    'AUT': 'Europe', 'BEL': 'Europe', 'BGR': 'Europe', 'HRV': 'Europe', 'CYP': 'Europe', 'CZE': 'Europe',
    'DNK': 'Europe', 'EST': 'Europe', 'FIN': 'Europe', 'FRA': 'Europe', 'DEU': 'Europe', 'GRC': 'Europe',
    'HUN': 'Europe', 'ISL': 'Europe', 'IRL': 'Europe', 'ITA': 'Europe', 'LVA': 'Europe', 'LTU': 'Europe',
    'LUX': 'Europe', 'MLT': 'Europe', 'NLD': 'Europe', 'NOR': 'Europe', 'POL': 'Europe', 'PRT': 'Europe',
    'ROU': 'Europe', 'SVK': 'Europe', 'SVN': 'Europe', 'ESP': 'Europe', 'SWE': 'Europe', 'CHE': 'Europe',
    'GBR': 'Europe', 'RUS': 'Europe', 'UKR': 'Europe',

    # Asia (All 48 countries)
    'AFG': 'Asia', 'ARM': 'Asia', 'AZE': 'Asia', 'BHR': 'Asia', 'BGD': 'Asia', 'BTN': 'Asia', 'BRN': 'Asia',
    'KHM': 'Asia', 'CHN': 'Asia', 'GEO': 'Asia', 'IND': 'Asia', 'IDN': 'Asia', 'IRN': 'Asia', 'IRQ': 'Asia',
    'ISR': 'Asia', 'JPN': 'Asia', 'JOR': 'Asia', 'KAZ': 'Asia', 'KWT': 'Asia', 'KGZ': 'Asia', 'LAO': 'Asia',
    'LBN': 'Asia', 'MYS': 'Asia', 'MDV': 'Asia', 'MNG': 'Asia', 'MMR': 'Asia', 'NPL': 'Asia', 'PRK': 'Asia',
    'OMN': 'Asia', 'PAK': 'Asia', 'PHL': 'Asia', 'QAT': 'Asia', 'SAU': 'Asia', 'SGP': 'Asia', 'KOR': 'Asia',
    'LKA': 'Asia', 'SYR': 'Asia', 'TWN': 'Asia', 'TJK': 'Asia', 'THA': 'Asia', 'TLS': 'Asia', 'TUR': 'Asia',
    'TKM': 'Asia', 'ARE': 'Asia', 'UZB': 'Asia', 'VNM': 'Asia', 'YEM': 'Asia',

    # Middle East (Overlaps some Asian countries but kept separate)
    'SAU': 'Middle East', 'IRN': 'Middle East', 'TUR': 'Middle East', 'ISR': 'Middle East', 'UAE': 'Middle East', 'QAT': 'Middle East',

    # Africa
    'ZAF': 'Africa', 'EGY': 'Africa', 'NGA': 'Africa', 'KEN': 'Africa', 'ETH': 'Africa', 'DZA': 'Africa', 'MAR': 'Africa',

    # Oceania
    'AUS': 'Oceania', 'NZL': 'Oceania', 'FJI': 'Oceania', 'PNG': 'Oceania'
}

# Assign regions based on country codes
df['REGION'] = df['LOCATION'].map(region_mapping)

# Remove rows where REGION is not assigned (if any)
df = df.dropna(subset=['REGION'])

# Save the classified dataset
df.to_csv("classified_renewable_energy.csv", index=False)
print("✅ Classification complete. Data saved as 'classified_renewable_energy.csv'.")
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.11/dist-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.11/dist-packages (from prophet) (0.69)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# ✅ Classification complete. Data saved as 'classified_renewable_energy.csv'.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from prophet import Prophet

# Convert 'TIME' column to datetime format
df['TIME'] = pd.to_datetime(df['TIME'], format='%Y')

# Aggregate data by Region and Time
region_time_series = df.groupby(['TIME', 'REGION'])['Value'].sum().reset_index()

# Get unique regions
regions = region_time_series['REGION'].unique()

# Forecast for each region
for region_name in regions:
    region_data = region_time_series[region_time_series['REGION'] == region_name]

    # Prepare Data for Prophet
    df_prophet = region_data.rename(columns={'TIME': 'ds', 'Value': 'y'})

    # Initialize and fit Prophet model
    model = Prophet()
    model.fit(df_prophet)

    # Ensure prediction extends to 2035
    future_years = 2035 - df_prophet['ds'].dt.year.max()
    future = model.make_future_dataframe(periods=future_years, freq='Y')
    forecast = model.predict(future)

    # Plot the forecast
    plt.figure(figsize=(10, 5))
    model.plot(forecast)
    plt.title(f"🌍 Renewable Energy Forecast for {region_name} (Up to 2035)")
    plt.xlabel("Year")
    plt.ylabel("Renewable Energy (Thousand TOE)")
    plt.show()
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/x6t_v49v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/sd8i8yuq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64665', 'data', 'file=/tmp/tmpmes9sitn/x6t_v49v.json', 'init=/tmp/tmpmes9sitn/sd8i8yuq.json', 'output', 'file=/tmp/tmpmes9sitn/prophet_modelj4k7v9qa/prophet_model-20250323094946.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.11/dist-packages/prophet/forecaster.py:1854: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/0mq01xm5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/41k13wrm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20568', 'data', 'file=/tmp/tmpmes9sitn/0mq01xm5.json', 'init=/tmp/tmpmes9sitn/41k13wrm.json', 'output', 'file=/tmp/tmpmes9sitn/prophet_modeltsoues8t/prophet_model-20250323094947.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.11/dist-packages/prophet/forecaster.py:1854: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/kk7ar5ea.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/au906i3z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28380', 'data', 'file=/tmp/tmpmes9sitn/kk7ar5ea.json', 'init=/tmp/tmpmes9sitn/au906i3z.json', 'output', 'file=/tmp/tmpmes9sitn/prophet_modelnvkosegw/prophet_model-20250323094948.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.11/dist-packages/prophet/forecaster.py:1854: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/ndtmu8n9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/kqf3ah86.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24034', 'data', 'file=/tmp/tmpmes9sitn/ndtmu8n9.json', 'init=/tmp/tmpmes9sitn/kqf3ah86.json', 'output', 'file=/tmp/tmpmes9sitn/prophet_model0vqq9v9l/prophet_model-20250323094949.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.11/dist-packages/prophet/forecaster.py:1854: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/ky_ikvfk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/cd2kdale.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=494', 'data', 'file=/tmp/tmpmes9sitn/ky_ikvfk.json', 'init=/tmp/tmpmes9sitn/cd2kdale.json', 'output', 'file=/tmp/tmpmes9sitn/prophet_modelsjbizg99/prophet_model-20250323094950.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.11/dist-packages/prophet/forecaster.py:1854: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/z0_cy9h2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/xwagzhr4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96811', 'data', 'file=/tmp/tmpmes9sitn/z0_cy9h2.json', 'init=/tmp/tmpmes9sitn/xwagzhr4.json', 'output', 'file=/tmp/tmpmes9sitn/prophet_modelusgv6t8b/prophet_model-20250323094950.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.11/dist-packages/prophet/forecaster.py:1854: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/ghy2xwnd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpmes9sitn/5q4kdiid.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25482', 'data', 'file=/tmp/tmpmes9sitn/ghy2xwnd.json', 'init=/tmp/tmpmes9sitn/5q4kdiid.json', 'output', 'file=/tmp/tmpmes9sitn/prophet_modelf_53ui72/prophet_model-20250323094951.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.11/dist-packages/prophet/forecaster.py:1854: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
